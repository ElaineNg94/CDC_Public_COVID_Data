# %%
# Install sodapy.
# !pip install sodapy
# Out:
# Collecting sodapy
#   Downloading sodapy-2.1.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: requests>=2.20.0 in c:\users\elain\anaconda3\envs\pythondata\lib\site-packages (from sodapy) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\elain\anaconda3\envs\pythondata\lib\site-packages (from requests>=2.20.0->sodapy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\elain\anaconda3\envs\pythondata\lib\site-packages (from requests>=2.20.0->sodapy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\elain\anaconda3\envs\pythondata\lib\site-packages (from requests>=2.20.0->sodapy) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\elain\anaconda3\envs\pythondata\lib\site-packages (from requests>=2.20.0->sodapy) (2020.6.20)
# Installing collected packages: sodapy
# Successfully installed sodapy-2.1.0

# %%
# Import dependencies.
import pandas as pd
from sodapy import Socrata

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cdc.gov", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cdc.gov,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("vbim-akqf", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
# View pandas DataFrame.
results_df
# Out:
#          cdc_case_earliest_dt            cdc_report_dt  \
# 0     2021-12-08T00:00:00.000  2021-12-13T00:00:00.000
# 1     2020-12-12T00:00:00.000  2020-12-16T00:00:00.000
# 2     2021-10-22T00:00:00.000  2021-10-26T00:00:00.000
# 3     2021-12-16T00:00:00.000  2021-12-16T00:00:00.000
# 4     2021-04-26T00:00:00.000  2021-05-24T00:00:00.000
# ...                       ...                      ...
# 1995  2020-12-04T00:00:00.000  2021-11-02T00:00:00.000
# 1996  2021-09-02T00:00:00.000  2021-11-02T00:00:00.000
# 1997  2020-10-29T00:00:00.000  2021-11-02T00:00:00.000
# 1998  2021-08-25T00:00:00.000  2021-08-25T00:00:00.000
# 1999  2021-02-24T00:00:00.000  2021-11-02T00:00:00.000
#
#                      onset_dt             current_status   sex      age_group  \
# 0     2021-12-08T00:00:00.000  Laboratory-confirmed case  Male  10 - 19 Years
# 1                         NaN  Laboratory-confirmed case  Male  10 - 19 Years
# 2     2021-10-22T00:00:00.000  Laboratory-confirmed case  Male  10 - 19 Years
# 3     2021-12-16T00:00:00.000  Laboratory-confirmed case  Male  10 - 19 Years
# 4     2021-04-26T00:00:00.000  Laboratory-confirmed case  Male  10 - 19 Years
# ...                       ...                        ...   ...            ...
# 1995  2020-12-04T00:00:00.000  Laboratory-confirmed case  Male  10 - 19 Years
# 1996                      NaN  Laboratory-confirmed case  Male  10 - 19 Years
# 1997                      NaN  Laboratory-confirmed case  Male  10 - 19 Years
# 1998                      NaN  Laboratory-confirmed case  Male  10 - 19 Years
# 1999                      NaN              Probable Case  Male  10 - 19 Years
#
#      race_ethnicity_combined  hosp_yn   icu_yn death_yn medcond_yn  \
# 0        Black, Non-Hispanic       No  Missing       No    Missing
# 1        Black, Non-Hispanic  Missing  Missing  Missing    Missing
# 2        Black, Non-Hispanic       No  Missing  Missing    Missing
# 3        Black, Non-Hispanic       No  Unknown       No    Unknown
# 4        Black, Non-Hispanic  Missing  Missing  Missing    Missing
# ...                      ...      ...      ...      ...        ...
# 1995     Black, Non-Hispanic  Unknown  Missing  Unknown    Missing
# 1996     Black, Non-Hispanic  Unknown  Missing  Unknown    Missing
# 1997     Black, Non-Hispanic  Unknown  Missing  Unknown    Missing
# 1998     Black, Non-Hispanic  Missing  Missing  Missing    Missing
# 1999     Black, Non-Hispanic  Unknown  Missing  Unknown    Missing
#
#                   pos_spec_dt
# 0                         NaN
# 1     2020-12-12T00:00:00.000
# 2                         NaN
# 3     2021-12-21T00:00:00.000
# 4                         NaN
# ...                       ...
# 1995  2020-12-03T00:00:00.000
# 1996  2021-09-02T00:00:00.000
# 1997  2020-10-29T00:00:00.000
# 1998                      NaN
# 1999  2021-02-24T00:00:00.000
#
# [2000 rows x 12 columns]
